# %% [markdown]
# # Algorithmic Trading Strategy

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
from IPython.display import Image, display
import pandas_ta as ta
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# #### User Defined Function
# List of functions that will be used in this notebook

# %%
# A function to download the data and standardize it into a desire format
def get_data(symbol):
    ticker = yf.Ticker(symbol)
    data = ticker.history(period='max', interval='1d') # in this example I'll use interday (daily timeframe)
    data.reset_index(inplace=True)
    data.columns = [c.lower().replace(' ', '_') for c in data.columns]
    return data

# %% [markdown]
# ### Download and Check Data
#
# We will use Google stock data from Yahoo Finance

# %%
data = get_data('GOOG')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5208 entries, 0 to 5207
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          5208 non-null   datetime64[ns, America/New_York]
#  1   open          5208 non-null   float64
#  2   high          5208 non-null   float64
#  3   low           5208 non-null   float64
#  4   close         5208 non-null   float64
#  5   volume        5208 non-null   int64
#  6   dividends     5208 non-null   float64
#  7   stock_splits  5208 non-null   float64
# dtypes: datetime64[ns, America/New_York](1), float64(6), int64(1)
# memory usage: 325.6 KB

# %%
data.describe().T
# Out:
#                count          mean           std            min           25%  \
# open          5208.0  4.965948e+01  4.869257e+01       2.458844  1.312577e+01
# high          5208.0  5.019155e+01  4.924506e+01       2.522057  1.327550e+01
# low           5208.0  4.915422e+01  4.819271e+01       2.378775  1.299582e+01
# close         5208.0  4.967971e+01  4.871956e+01       2.479171  1.312881e+01
# volume        5208.0  1.122896e+08  1.481586e+08  158434.000000  2.638895e+07
# dividends     5208.0  1.536098e-04  5.541143e-03       0.000000  0.000000e+00
# stock_splits  5208.0  4.417194e-03  2.788602e-01       0.000000  0.000000e+00
#
#                        50%           75%           max
# open          2.796317e+01  6.712582e+01  2.042673e+02
# high          2.819017e+01  6.767185e+01  2.084625e+02
# low           2.771698e+01  6.659109e+01  2.040275e+02
# close         2.788793e+01  6.711735e+01  2.074736e+02
# volume        5.106000e+07  1.368229e+08  1.650833e+09
# ...

# %%
data.head()
# Out:
#                        date      open      high       low     close  \
# 0 2004-08-19 00:00:00-04:00  2.478923  2.579567  2.378775  2.487352
# 1 2004-08-20 00:00:00-04:00  2.503960  2.704009  2.491318  2.684922
# 2 2004-08-23 00:00:00-04:00  2.745407  2.813082  2.703266  2.711942
# 3 2004-08-24 00:00:00-04:00  2.757554  2.766478  2.567421  2.599647
# 4 2004-08-25 00:00:00-04:00  2.601877  2.677238  2.575105  2.627658
#
#       volume  dividends  stock_splits
# 0  897427216        0.0           0.0
# 1  458857488        0.0           0.0
# 2  366857939        0.0           0.0
# 3  306396159        0.0           0.0
# 4  184645512        0.0           0.0

# %%
print(data.date.min())
print(data.date.max())
# Out:
# 2004-08-19 00:00:00-04:00
# 2025-04-30 00:00:00-04:00

# %%
fig = go.Figure()

fig.add_trace(go.Candlestick(
    x=data.date,
    open=data.open,
    high=data.high,
    low=data.low,
    close=data.close,
    name='OHLC'
))

fig.write_image("./assets/plot1.png")  
display(Image("./assets/plot1.png"))

# Uncomment below fig for interactive plot in your local
# fig.show()

# %% [markdown]
# **Summary**: The Google stock data obtained from Yahoo Finance consists of 5,208 records, with no missing values found in any of the columns. The data covers the period from August 2004 to April 2025.

# %% [markdown]
# ### Market Trend
#
# The market trend is essentially a general direction in which the price of a financial asset is moving over a period of time. It can be either upward (bullish) or downward (bearish). <br/>
# In this notebook we will use Moving Average (MA) and Average Directional Index (ADX) to detect the trend.

# %% [markdown]
# #### Market Trend - Moving Average
#
# MA is a fundamental trend indicator used to smooth out price data and identify trend over a specified period of time

# %%
# We will compute and plot 2 types of MA in this example,
# one is for 5 days window of the closing price another for 30 days window of the closing price

data['ma_5'] = data['close'].rolling(window=5).mean()
data['ma_30'] = data['close'].rolling(window=30).mean()

# %%
data.head(7)
# Out:
#                        date      open      high       low     close  \
# 0 2004-08-19 00:00:00-04:00  2.478923  2.579567  2.378775  2.487352
# 1 2004-08-20 00:00:00-04:00  2.503960  2.704009  2.491318  2.684922
# 2 2004-08-23 00:00:00-04:00  2.745407  2.813082  2.703266  2.711942
# 3 2004-08-24 00:00:00-04:00  2.757554  2.766478  2.567421  2.599647
# 4 2004-08-25 00:00:00-04:00  2.601877  2.677238  2.575105  2.627658
# 5 2004-08-26 00:00:00-04:00  2.601629  2.675997  2.594441  2.675006
# 6 2004-08-27 00:00:00-04:00  2.679716  2.692607  2.619974  2.631377
#
#       volume  dividends  stock_splits      ma_5  ma_30
# 0  897427216        0.0           0.0       NaN    NaN
# 1  458857488        0.0           0.0       NaN    NaN
# 2  366857939        0.0           0.0       NaN    NaN
# 3  306396159        0.0           0.0       NaN    NaN
# 4  184645512        0.0           0.0  2.622304    NaN
# 5  142572401        0.0           0.0  2.659835    NaN
# ...

# %%
# Visualize the MA along with the candle for last 360 days
df = data.sort_values(by='date', ascending=False)[:360]

fig = go.Figure()
fig.add_trace(go.Candlestick(
    x=df.date,
    open=df.open,
    high=df.high,
    low=df.low,
    close=df.close,
    name='OHLC'
))

fig.add_trace(
    go.Scatter(
        x=df.date,
        y=df.ma_5,
        mode='lines',
        line=dict(color='blue', width=2),
        name='MA_5'
    )
)

fig.add_trace(
    go.Scatter(
        x=df.date,
        y=df.ma_30,
        mode='lines',
        line=dict(color='orange', width=2), 
        name='MA_30'
    )
)

fig.update_layout(
    xaxis=dict(rangeslider=dict(visible=False))
)

fig.write_image("./assets/plot2.png")  
display(Image("./assets/plot2.png"))

# Uncomment below fig for interactive plot in your local
# fig.show()

# %% [markdown]
# ### Market Trend - The Average Directional Index (ADX)
# ADX helps us to determine the strength of a trend.<br/>
# The ADX value ranges from 0 to 100:
# - 0-20: weak trend
# - 20-40: developing trend, but it may still be considered weak
# - 40-60: indicates a relatively strong trend
# - 60-100: suggests an extremely strong trend

# %%
data.ta.adx(length=14, append=True)
# Out:
#          ADX_14     DMP_14     DMN_14
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2           NaN        NaN        NaN
# 3           NaN        NaN        NaN
# 4           NaN        NaN        NaN
# ...         ...        ...        ...
# 5203  34.643769  23.346881  26.762268
# 5204  32.795066  29.303230  24.581858
# 5205  30.617889  27.664707  26.413030
# 5206  28.437710  26.515239  26.565867
# 5207  26.799777  24.856997  27.754106
#
# [5208 rows x 3 columns]

# %%
data.columns = [c.lower() for c in data.columns]

# %%
data.tail()
# Out:
#                           date        open        high         low  \
# 5203 2025-04-24 00:00:00-04:00  158.524994  161.710007  158.089996
# 5204 2025-04-25 00:00:00-04:00  167.100006  168.240005  163.000000
# 5205 2025-04-28 00:00:00-04:00  164.259995  164.949997  160.380005
# 5206 2025-04-29 00:00:00-04:00  162.044998  162.679993  159.389999
# 5207 2025-04-30 00:00:00-04:00  159.860001  161.373993  157.154999
#
#            close    volume  dividends  stock_splits        ma_5       ma_30  \
# 5203  161.470001  30787500        0.0           0.0  155.262000  159.570666
# 5204  163.850006  35148100        0.0           0.0  157.360001  159.541333
# 5205  162.419998  20871200        0.0           0.0  159.872000  159.368000
# 5206  162.059998  15955200        0.0           0.0  161.504001  159.217666
# 5207  160.889999  20516400        0.0           0.0  162.138000  159.158333
#
#          adx_14     dmp_14     dmn_14
# 5203  34.643769  23.346881  26.762268
# ...

# %%
# Visualize the MA along with the candle for last 360 days
df = data.sort_values(by='date', ascending=False)[:360]

fig = make_subplots(rows=2, cols=1, shared_xaxes=True)

fig.add_trace(go.Candlestick(
    x=df.date,
    open=df.open,
    high=df.high,
    low=df.low,
    close=df.close,
    name='OHLC'
), row=1, col=1)

fig.add_trace(
    go.Scatter(
        x=df.date,
        y=df.ma_5,
        mode='lines',
        line=dict(color='blue', width=2),
        name='MA_5'
    ), row=1, col=1
)

fig.add_trace(
    go.Scatter(
        x=df.date,
        y=df.ma_30,
        mode='lines',
        line=dict(color='orange', width=2), 
        name='MA_30'
    ), row=1, col=1
)

fig.add_trace(
    go.Scatter(
        x=df.date,
        y=df.adx_14,
        mode='lines',
        line=dict(color='MediumPurple', width=2), 
        name='ADX_14'
    ), row=2, col=1
)

fig.update_layout(
    xaxis=dict(rangeslider=dict(visible=False))
)

fig.write_image("./assets/plot3.png")  
display(Image("./assets/plot3.png"))

# Uncomment below fig for interactive plot in your local
# fig.show()
